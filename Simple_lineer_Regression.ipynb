# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
df = pd.read_csv("1-studyhours.csv")

# %%
plt.scatter(df["Study Hours"],df["Exam Score"])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.show()

# %%
X = df[["Study Hours"]]
y = df["Exam Score"]
type(X)#seridir algoritma x'i df olarak ister.
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)#seridir algoritma y'yi seri olarak ister
# Out:
# pandas.core.series.Series

# %%
#test-train split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=15)

# %%
#standardize the data set

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()#kolonlar arasındaki büyük değer
                         #farklılıklarını gidermek için scaler kullanılır.

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[ 0.11794385],
#        [-0.97424848],
#        [-1.68837424],
#        [ 0.32798083],
#        [ 0.36998823],
#        [-0.7222041 ],
#        [ 0.41199563],
#        [-0.97424848],
#        [ 0.11794385],
#        [-0.30213013],
#        [ 0.15995124],
#        [ 0.66404001],
#        [-0.13410054],
#        [ 1.50418796],
#        [-0.51216711],
#        [ 0.15995124],
#        [-0.30213013],
#        [ 1.21013618],
#        [ 1.33615837],
#        [ 0.7900622 ],
#        [-1.77238903],
#        [-1.89841122],
#        [ 0.20195864],
#        [ 1.88225453],
#        [-1.18428547],
#        [ 1.21013618]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("coefficient:",regression.coef_)
print("Intercept:",regression.intercept_
# Out:
#   Cell In[13], line 2
#     print("Intercept:",regression.intercept_
#                                             ^
# _IncompleteInputError: incomplete input

# %%
# y = 76.91 + 16.18x

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train),"r")
plt.show()

# %%
prediction = regression.predict(scaler.transform([[20]]))
prediction

# %%
#prediction with test data

# %%
y_pred_test = regression.predict(X_test)

# %%
plt.scatter(y_pred_test,y_test)
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred_test)
mae=mean_absolute_error(y_test,y_pred_test)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 29.45839048833392
# 4.054868128856142
# 5.427558427906043

# %%
from sklearn.metrics import r2_score
